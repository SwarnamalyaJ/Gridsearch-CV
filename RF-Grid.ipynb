# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
indep
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
depn=dataset[["charges"]]
depn
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,depn,test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler 
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV 
param_grid={'criterion':["squared error","friedman_mse","absolute error","poisson"],'max_features':[None,'sqrt','log2'],'n_estimators':[10,50,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 90 fits failed out of a total of 180.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'friedman_mse', 'poisson', 'squared_error', 'absolute_error'}. Got 'squared error' instead.
#
# --------------------------------------------------------------------------------
# 9 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'squared_error', 'absolute_error', 'friedman_mse'}. Got 'squared error' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'squared_error', 'friedman_mse', 'poisson', 'absolute_error'}. Got 'squared error' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'friedman_mse', 'absolute_error', 'poisson', 'squared_error'}. Got 'squared error' instead.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'squared_error', 'friedman_mse', 'absolute_error', 'poisson'}. Got 'squared error' instead.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'friedman_mse', 'squared_error', 'absolute_error', 'poisson'}. Got 'squared error' instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'absolute_error', 'squared_error', 'friedman_mse'}. Got 'squared error' instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'friedman_mse', 'absolute_error', 'squared_error'}. Got 'squared error' instead.
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'friedman_mse', 'squared_error', 'absolute_error'}. Got 'squared error' instead.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'absolute_error', 'squared_error', 'friedman_mse'}. Got 'absolute error' instead.
#
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'squared_error', 'absolute_error', 'friedman_mse'}. Got 'absolute error' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.79683972 0.80142716 0.80106304
#  0.80048351 0.81398726 0.81389795 0.79363606 0.8162071  0.81126844
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.79065139 0.80295428 0.80723384
#  0.78673555 0.80722738 0.81251846 0.78601796 0.8101395  0.81228735]
#   warnings.warn(
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared error', 'friedman_mse',
#                                        'absolute error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100]},
#              verbose=3)

# %%
best_model = grid.best_estimator_

# %%
y_pred = best_model.predict(x_test)

# %%
re=grid.cv_results_
print=("best_parameter{}:".format(grid.best_params_))

# %%
print
# Out:
# "best_parameter{'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 50}:"

# %%
 table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000000      0.000000         0.000000    0.000000e+00
# 1        0.003131      0.006262         0.000000    0.000000e+00
# 2        0.000000      0.000000         0.000000    0.000000e+00
# 3        0.003148      0.006296         0.000000    0.000000e+00
# 4        0.000000      0.000000         0.000000    0.000000e+00
# 5        0.000000      0.000000         0.000000    0.000000e+00
# 6        0.000000      0.000000         0.000000    0.000000e+00
# 7        0.003196      0.006391         0.000000    0.000000e+00
# 8        0.003164      0.006328         0.000000    0.000000e+00
# 9        0.103244      0.027227         0.006249    7.653955e-03
# 10       0.529764      0.116063         0.015623    7.921814e-07
# 11       1.095014      0.167427         0.023914    1.012234e-02
# 12       0.250151      0.098734         0.007026    6.223860e-03
# 13       0.466293      0.112471         0.018812    1.505131e-02
# 14       0.689472      0.043226         0.018748    6.249690e-03
# 15       0.072156      0.009271         0.004737    6.277030e-03
# 16       0.331560      0.043797         0.015702    1.000608e-02
# 17       0.636375      0.014049         0.021968    7.771979e-03
# 18       0.000000      0.000000         0.000000    0.000000e+00
# 19       0.001001      0.002001         0.000000    0.000000e+00
# 20       0.001600      0.003201         0.000000    0.000000e+00
# 21       0.000000      0.000000         0.000000    0.000000e+00
# 22       0.000000      0.000000         0.000000    0.000000e+00
# 23       0.000000      0.000000         0.000000    0.000000e+00
# 24       0.003125      0.006250         0.000000    0.000000e+00
# 25       0.002302      0.004603         0.000000    0.000000e+00
# 26       0.000000      0.000000         0.000000    0.000000e+00
# 27       0.121900      0.020755         0.006250    7.654130e-03
# 28       0.510071      0.007567         0.012498    6.248954e-03
# 29       0.950876      0.049305         0.015624    6.106495e-07
# 30       0.085224      0.007048         0.003125    6.249619e-03
# 31       0.344138      0.017123         0.012498    6.249046e-03
# 32       0.622290      0.057161         0.024998    7.653721e-03
# 33       0.075230      0.006370         0.003125    6.249046e-03
# 34       0.340588      0.006249         0.012498    6.249142e-03
# 35       0.569080      0.039027         0.012499    6.249523e-03
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared error               None                 10
# 1    squared error               None                 50
# 2    squared error               None                100
# 3    squared error               sqrt                 10
# 4    squared error               sqrt                 50
# 5    squared error               sqrt                100
# 6    squared error               log2                 10
# 7    squared error               log2                 50
# 8    squared error               log2                100
# 9     friedman_mse               None                 10
# 10    friedman_mse               None                 50
# 11    friedman_mse               None                100
# 12    friedman_mse               sqrt                 10
# 13    friedman_mse               sqrt                 50
# 14    friedman_mse               sqrt                100
# 15    friedman_mse               log2                 10
# 16    friedman_mse               log2                 50
# 17    friedman_mse               log2                100
# 18  absolute error               None                 10
# 19  absolute error               None                 50
# 20  absolute error               None                100
# 21  absolute error               sqrt                 10
# 22  absolute error               sqrt                 50
# 23  absolute error               sqrt                100
# 24  absolute error               log2                 10
# 25  absolute error               log2                 50
# 26  absolute error               log2                100
# 27         poisson               None                 10
# 28         poisson               None                 50
# 29         poisson               None                100
# 30         poisson               sqrt                 10
# 31         poisson               sqrt                 50
# 32         poisson               sqrt                100
# 33         poisson               log2                 10
# 34         poisson               log2                 50
# 35         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared error', 'max_features':...                NaN
# 1   {'criterion': 'squared error', 'max_features':...                NaN
# 2   {'criterion': 'squared error', 'max_features':...                NaN
# 3   {'criterion': 'squared error', 'max_features':...                NaN
# 4   {'criterion': 'squared error', 'max_features':...                NaN
# 5   {'criterion': 'squared error', 'max_features':...                NaN
# 6   {'criterion': 'squared error', 'max_features':...                NaN
# 7   {'criterion': 'squared error', 'max_features':...                NaN
# 8   {'criterion': 'squared error', 'max_features':...                NaN
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.857102
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.853398
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.859965
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.845128
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.866053
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.866588
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.858195
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.874114
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.858816
# 18  {'criterion': 'absolute error', 'max_features'...                NaN
# 19  {'criterion': 'absolute error', 'max_features'...                NaN
# 20  {'criterion': 'absolute error', 'max_features'...                NaN
# 21  {'criterion': 'absolute error', 'max_features'...                NaN
# 22  {'criterion': 'absolute error', 'max_features'...                NaN
# 23  {'criterion': 'absolute error', 'max_features'...                NaN
# 24  {'criterion': 'absolute error', 'max_features'...                NaN
# 25  {'criterion': 'absolute error', 'max_features'...                NaN
# 26  {'criterion': 'absolute error', 'max_features'...                NaN
# 27  {'criterion': 'poisson', 'max_features': None,...           0.860176
# 28  {'criterion': 'poisson', 'max_features': None,...           0.863574
# 29  {'criterion': 'poisson', 'max_features': None,...           0.869534
# 30  {'criterion': 'poisson', 'max_features': 'sqrt...           0.821664
# 31  {'criterion': 'poisson', 'max_features': 'sqrt...           0.859819
# 32  {'criterion': 'poisson', 'max_features': 'sqrt...           0.860444
# 33  {'criterion': 'poisson', 'max_features': 'log2...           0.826555
# 34  {'criterion': 'poisson', 'max_features': 'log2...           0.862093
# 35  {'criterion': 'poisson', 'max_features': 'log2...           0.861375
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9            0.755990           0.809597           0.802734
# 10           0.763885           0.814868           0.803319
# 11           0.759602           0.814694           0.807043
# 12           0.794066           0.802736           0.807586
# 13           0.800221           0.811580           0.821071
# 14           0.790930           0.806331           0.832489
# 15           0.775735           0.765296           0.807805
# 16           0.790223           0.804982           0.834086
# 17           0.795315           0.804380           0.827795
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26                NaN                NaN                NaN
# 27           0.747718           0.808963           0.772302
# 28           0.778025           0.809655           0.798080
# 29           0.770985           0.814501           0.811651
# 30           0.771815           0.786314           0.809669
# 31           0.779641           0.800896           0.825220
# 32           0.793272           0.813990           0.824831
# 33           0.775918           0.784853           0.799865
# 34           0.792891           0.810615           0.821890
# 35           0.787218           0.813266           0.826564
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               19
# 1                 NaN              NaN             NaN               19
# 2                 NaN              NaN             NaN               19
# 3                 NaN              NaN             NaN               19
# 4                 NaN              NaN             NaN               19
# 5                 NaN              NaN             NaN               19
# 6                 NaN              NaN             NaN               19
# 7                 NaN              NaN             NaN               19
# 8                 NaN              NaN             NaN               19
# 9            0.758776         0.796840        0.037274               14
# 10           0.771665         0.801427        0.032188               11
# 11           0.764011         0.801063        0.036832               12
# 12           0.752902         0.800484        0.029509               13
# 13           0.771011         0.813987        0.030994                2
# 14           0.773151         0.813898        0.032763                3
# 15           0.761149         0.793636        0.036187               15
# 16           0.777630         0.816207        0.034532                1
# 17           0.770036         0.811268        0.030119                6
# 18                NaN              NaN             NaN               19
# 19                NaN              NaN             NaN               19
# 20                NaN              NaN             NaN               19
# 21                NaN              NaN             NaN               19
# 22                NaN              NaN             NaN               19
# 23                NaN              NaN             NaN               19
# 24                NaN              NaN             NaN               19
# 25                NaN              NaN             NaN               19
# 26                NaN              NaN             NaN               19
# 27           0.764098         0.790651        0.040135               16
# 28           0.765437         0.802954        0.033978               10
# 29           0.769498         0.807234        0.036583                8
# 30           0.744217         0.786736        0.027483               17
# 31           0.770561         0.807227        0.032358                9
# 32           0.770055         0.812518        0.030411                4
# 33           0.742898         0.786018        0.027560               18
# 34           0.763208         0.810140        0.032672                7
# 35           0.773013         0.812287        0.030937                5

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:34
# BMI:29
# Children:2
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print=("Future_prediction={}".format(Future_Prediction))

# %%
print
# Out:
# 'Future_prediction=[13974.153855]'

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.8724861122944079
