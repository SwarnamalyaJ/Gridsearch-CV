# %%
import numpy as np
import matplotlib as pyplot
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'kernel':['rbf','sigmoid','linear'],'C':[10,1000,2000,3000,4000] ,'gamma':['auto','scale']}

grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)

grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 1000, 2000, 3000, 4000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'sigmoid', 'linear']},
#              verbose=3)

# %%
best_model = grid.best_estimator_

# %%
y_pred = best_model.predict(independent)

# %%
re= grid.cv_results_
print=("Best_parameters{}:".format(grid.best_params_))

# %%
print
# Out:
# "Best_parameters{'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}:"

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.250015      0.070651         0.107632    1.756691e-02      10
# 1        0.240596      0.030615         0.040068    8.681264e-03      10
# 2        0.259512      0.083661         0.033011    1.049145e-02      10
# 3        0.325167      0.082316         0.162533    6.916223e-02      10
# 4        0.314727      0.088362         0.063487    3.076965e-02      10
# 5        0.211499      0.036314         0.023975    1.074905e-02      10
# 6        0.395131      0.120293         0.162619    5.812745e-02    1000
# 7        0.190604      0.033362         0.039080    1.377162e-02    1000
# 8        1.171696      0.102357         0.028125    6.250576e-03    1000
# 9        0.261030      0.038989         0.131236    4.025852e-02    1000
# 10       0.271845      0.042615         0.048025    1.932356e-03    1000
# 11       1.004766      0.105098         0.024998    7.654149e-03    1000
# 12       0.325518      0.025417         0.086606    6.856550e-03    2000
# 13       0.128266      0.005888         0.028121    6.248641e-03    2000
# 14       1.565047      0.095360         0.018951    6.160449e-03    2000
# 15       0.188481      0.000802         0.087531    7.688264e-03    2000
# 16       0.209629      0.007596         0.048869    2.461021e-03    2000
# 17       1.528991      0.079548         0.021873    7.653624e-03    2000
# 18       0.354550      0.013611         0.088508    6.605992e-03    3000
# 19       0.133006      0.004091         0.029767    3.252089e-03    3000
# 20       2.865433      0.647711         0.028124    6.249356e-03    3000
# 21       0.189337      0.007042         0.093903    1.001442e-02    3000
# 22       0.210167      0.012581         0.046821    3.223138e-04    3000
# 23       2.859778      0.657829         0.024998    7.653799e-03    3000
# 24       0.389640      0.008361         0.080815    5.206594e-03    4000
# 25       0.134406      0.012579         0.021873    7.654675e-03    4000
# 26       3.251693      0.822768         0.021873    7.653566e-03    4000
# 27       0.184354      0.006250         0.084366    7.654071e-03    4000
# 28       0.193729      0.007654         0.046870    9.172146e-07    4000
# 29       2.756518      0.768994         0.012497    6.248690e-03    4000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto      sigmoid
# 2         auto       linear
# 3        scale          rbf
# 4        scale      sigmoid
# 5        scale       linear
# 6         auto          rbf
# 7         auto      sigmoid
# 8         auto       linear
# 9        scale          rbf
# 10       scale      sigmoid
# 11       scale       linear
# 12        auto          rbf
# 13        auto      sigmoid
# 14        auto       linear
# 15       scale          rbf
# 16       scale      sigmoid
# 17       scale       linear
# 18        auto          rbf
# 19        auto      sigmoid
# 20        auto       linear
# 21       scale          rbf
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto      sigmoid
# 26        auto       linear
# 27       scale          rbf
# 28       scale      sigmoid
# 29       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.113791
# 1     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 2      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.018943
# 3        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.110409
# 4    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.116743
# 5     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.018943
# 6       {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.080692
# 7   {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 8    {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.736398
# 9      {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.155430
# 10  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...          -2.043140
# 11  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.736398
# 12      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.033126
# 13  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 14   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.682349
# 15     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.143510
# 16  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -7.209317
# 17  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.682349
# 18      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.011741
# 19  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 20   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.677778
# 21     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.128958
# 22  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...         -15.561853
# 23  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.677778
# 24      {'C': 4000, 'gamma': 'auto', 'kernel': 'rbf'}           0.056023
# 25  {'C': 4000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 26   {'C': 4000, 'gamma': 'auto', 'kernel': 'linear'}           0.675782
# 27     {'C': 4000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.115990
# 28  {'C': 4000, 'gamma': 'scale', 'kernel': 'sigmo...         -26.856755
# 29  {'C': 4000, 'gamma': 'scale', 'kernel': 'linear'}           0.675782
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.110741          -0.079156          -0.103389
# 1           -0.113567          -0.081608          -0.106067
# 2            0.029886           0.022167           0.003112
# 3           -0.097459          -0.074488          -0.099597
# 4           -0.119312          -0.085214          -0.108210
# 5            0.029886           0.022167           0.003112
# 6           -0.054347          -0.062876          -0.079329
# 7           -0.113567          -0.081608          -0.106067
# 8            0.675162           0.680002           0.699377
# 9           -0.098267          -0.123724          -0.137137
# 10          -2.686121          -2.194563          -2.210858
# 11           0.675162           0.680002           0.699377
# 12          -0.002835          -0.026545          -0.029140
# 13          -0.113567          -0.081608          -0.106067
# 14           0.630642           0.750714           0.646368
# 15          -0.087595          -0.113312          -0.128591
# 16          -9.282940          -7.776578          -7.745074
# 17           0.630642           0.750714           0.646368
# 18           0.043659           0.013383           0.021694
# 19          -0.113567          -0.081608          -0.106067
# 20           0.626814           0.732806           0.633479
# 21          -0.075578          -0.100199          -0.116051
# 22         -20.498908         -17.095474         -16.750877
# 23           0.626814           0.732806           0.633479
# 24           0.086447           0.051315           0.068783
# 25          -0.113567          -0.081608          -0.106067
# 26           0.622362           0.732388           0.633010
# 27          -0.063068          -0.085738          -0.103877
# 28         -35.645101         -29.930262         -29.127891
# 29           0.622362           0.732388           0.633010
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.106488        -0.102713        0.012303               16
# 1           -0.107195        -0.104753        0.012107               17
# 2           -0.066653        -0.006086        0.034672               11
# 3           -0.124428        -0.101276        0.016459               15
# 4           -0.108716        -0.107639        0.012029               23
# 5           -0.066653        -0.006086        0.034672               11
# 6           -0.117983        -0.079045        0.021865               14
# 7           -0.107195        -0.104753        0.012107               17
# 8            0.677952         0.693778        0.022955                1
# 9           -0.206405        -0.144193        0.036262               26
# 10          -1.942521        -2.215441        0.255409               27
# 11           0.677952         0.693778        0.022955                1
# 12          -0.067392        -0.031808        0.020699               13
# 13          -0.107195        -0.104753        0.012107               17
# 14           0.722261         0.686467        0.045056                3
# 15          -0.193992        -0.133400        0.035492               25
# 16          -6.891719        -7.781126        0.821557               28
# 17           0.722261         0.686467        0.045056                3
# 18          -0.012948         0.015506        0.018217               10
# 19          -0.107195        -0.104753        0.012107               17
# 20           0.698692         0.673914        0.039876                5
# 21          -0.179304        -0.120018        0.034578               24
# 22         -15.012168       -16.983856        1.914783               29
# 23           0.698692         0.673914        0.039876                5
# 24           0.040278         0.060569        0.015844                9
# 25          -0.107195        -0.104753        0.012107               17
# 26           0.694627         0.671634        0.040389                7
# 27          -0.165535        -0.106842        0.034348               22
# 28         -26.011785       -29.514359        3.383466               30
# 29           0.694627         0.671634        0.040389                7

# %%
age_input=float(input("age:"))
bmi_input=float(input("bmi:"))
children_input=float(input("children:"))
sex_male_input=int(input("sex_male 0 or 1:"))
smoker_yes_input=int(input("smoker_yes 0 or 1:"))
# Out:
# age:32
# bmi:28
# children:2
# sex_male 0 or 1:0
# smoker_yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print=("Future_Prediction={}".format(Future_Prediction))
# Out:
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
print
# Out:
# 'Future_Prediction=[30190.29039795]'

# %%
from sklearn.metrics import r2_score
r_score=r2_score(dependent,y_pred)
r_score
# Out:
# 0.7179049746029832
